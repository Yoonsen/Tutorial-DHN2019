# %% [markdown]
# ### Preamble
#
# Contains imports and some utility code.

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
update('nbtext', overwrite=True)  # may remove overwrite=True
update('graph_networkx_louvain', overwrite=True)
import graph_networkx_louvain as gnl
import nbtext as nb
import networkx as nx
# %matplotlib inline
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Tutorial-DHN2019\nbtext.py`
# Updated file `C:\Users\larsj\Documents\GitHub\Tutorial-DHN2019\graph_networkx_louvain.py`

# %%
def frame_sort(frame, by=0):
    return frame.sort_values(by=by, ascending=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Collocations
#
# The term collocation has traditionally been restricted to words that are juxtaposed together as phrases like “strong coffee”, “strict regime” or “eat dinner”. Here we take collocations to be realized as skipgrams, or as word pairs that simply cooccur within a context which in itself is a contiguous sequence of words, typically a paragraph or a window of n words around a given word. Juxtaposed collocates will also be part of the result set.

# %% [markdown]
# ### Define a corpus
#
# Using dewey decimal to restrict corpus

# %%
corpus_urns = nb.get_urn({
    'ddk':"641.2%", 
    'year':1960, 
    'next':60, 
    'lang':'nob', 
    'limit': 200
})

print(len(corpus_urns), corpus_urns[:5])
# Out:
# 169 [[2013011607199, 'Marthinsen, Tom', 'Vinens vinnere 2006', 2005], [2016070548078, 'Clarke, Oz', 'Druer og viner fra hele verden', 2002], [2014102848156, 'Ronold, Arne', 'Norges beste vinkjøp 2005', 2004], [2014102848174, 'Lundberg, Stig', 'Vinglede', 2001], [2013091638058, 'Hoffmann, Marc A.', 'Whisky', 2009]]

# %% [markdown]
# ### Make a collocation for a word from the corpus
#
# Here we go step by step. The process may be collected into one general script.
#
# First, collect the words around a given word and count the result.

# %%
collword = 'rødvin'

# %%
rødvin = nb.urn_coll('rødvin', urns = corpus_urns, after = 5, before = 5, limit = 1000)

# %%
rødvin.head()
# Out:
#        0
# ,   3442
# .   3112
# og  2002
# en  1945
# er  1228

# %% [markdown]
# We want to measure how this differs from a reference. Two point themselves out, the collection of all books, and the corpus itself.
#
# All books

# %%
tot = nb.frame(nb.totals(top = 50000))

# %%
tot.head()
# Out:
#               0
# .    1265723110
# ,    1105303412
# og    543432056
# i     460246057
# det   273411583

# %% [markdown]
# The corpus

# %%
corpus_tot = nb.aggregate_urns(corpus_urns)

# %% [markdown]
# Make it into a frame

# %%
corpus_tot = frame_sort(nb.frame(corpus_tot))

# %%
corpus_tot.head()
# Out:
#          0
# ,   709798
# .   586482
# og  361930
# i   277920
# er  218205

# %% [markdown]
# So we have three wordbags, the collocation, the corpus counts, and the total count of all books. Let us also normalize them, so values more easily can be compared.

# %%
nb.normalize_corpus_dataframe(corpus_tot)
nb.normalize_corpus_dataframe(tot)
nb.normalize_corpus_dataframe(rødvin)
# Out:
# True

# %%
coll_all = frame_sort(rødvin**1.0/tot)

# %%
coll_all.head(20)
# Out:
#                         0
# hvitvin       3962.766229
# Bordeaux       750.518510
# Kraftig        648.793316
# rødvin         626.435502
# fyldig         547.990075
# drikkes        439.359617
# Chateau        406.508348
# druer          352.769189
# saftig         325.909706
# portvin        323.628645
# portugisisk    320.815149
# druene         291.847932
# viner          273.091767
# vinene         268.071337
# Enkel          240.959032
# Vinmonopolet   239.110352
# Frisk          237.515055
# Spanias        216.465779
# Blanc          214.877245
# Italiensk      211.791589

# %% [markdown]
# Compare the effect of exponent choice below. The formula for computing the collocation is:
#
# $coll(x)=\frac{x^e}{r(x)}$ for some exponent $e$ and reference value $r(x)$ for $x$. The formula makes sure that higher values of $x$ compared to $r(x)$, scores higher, and the exponent penalizes small values of $x$, compared to the corpus.
#
# Look at the values, and note where the numbers are equal. In a real situation, one may want to remove all hapax from the corpus.
#
# In Python, the computation takes the following form:

# %%
coll_corp = frame_sort(rødvin**1.7/corpus_tot)

# %%
coll_corp.head(20)
# Out:
#                           0
# hvitvin            1.241043
# Karbonader         1.111235
# Fordeling          0.719082
# Fettstrukturen     0.481387
# tanninholdig       0.469637
# rosévin            0.466143
# fiskefettet        0.444494
# tilberedningsform  0.407538
# jordbærsmakende    0.370412
# fordre             0.361040
# tanninsvak         0.361040
# vintype:           0.343344
# Wienersnitsel      0.343344
# T3IH1in            0.343344
# Suffleer           0.343344
# Kjøttfondue        0.343344
# Kjøttfondy         0.343344
# bodeaux            0.343344
# tannindominert     0.331023
# Hare               0.317496

# %% [markdown]
# A quick check with concordances may point to:

# %%
nb.get_urnkonk('Enkel', {'urns':corpus_urns, 'limit':50})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011607199?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinens vinnere 2006, Marthinsen, Tom, 2005</a>
#                 </td>
#                 <td>vin med tørr avslutning .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, men god . PASSER</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011607199?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinens vinnere 2006, Marthinsen, Tom, 2005</a>
#                 </td>
#                 <td>likevel tett og fyldig .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>men veldig god .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011607199?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinens vinnere 2006, Marthinsen, Tom, 2005</a>
#                 </td>
#                 <td>med et voldsomt mandelpreg .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, men frisk og god</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011607199?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinens vinnere 2006, Marthinsen, Tom, 2005</a>
#                 </td>
#                 <td>passe fyldig . Balansert .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, men en veldig god</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011607199?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinens vinnere 2006, Marthinsen, Tom, 2005</a>
#                 </td>
#                 <td>AV EPLER og markjordbær .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, myk , snill ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548078?searchText=Enkel' target='_blank' style='text-decoration:none'>Druer og viner fra hele verden, Clarke, Oz, 2002</a>
#                 </td>
#                 <td>drikkes med en gang .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>chablis trenger to — tre</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548078?searchText=Enkel' target='_blank' style='text-decoration:none'>Druer og viner fra hele verden, Clarke, Oz, 2002</a>
#                 </td>
#                 <td>Regnié og St-Amour ) .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>beaujolais kommer fra den flate</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548078?searchText=Enkel' target='_blank' style='text-decoration:none'>Druer og viner fra hele verden, Clarke, Oz, 2002</a>
#                 </td>
#                 <td>None</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, søt , druepreget Muskatell</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548078?searchText=Enkel' target='_blank' style='text-decoration:none'>Druer og viner fra hele verden, Clarke, Oz, 2002</a>
#                 </td>
#                 <td>enn lenger nord i 1999.</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>chiantl er bra eller svært</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548078?searchText=Enkel' target='_blank' style='text-decoration:none'>Druer og viner fra hele verden, Clarke, Oz, 2002</a>
#                 </td>
#                 <td>None</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>bordeaux blanc skal drikkes innen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102848156?searchText=Enkel' target='_blank' style='text-decoration:none'>Norges beste vinkjøp 2005, Ronold, Arne, 2004</a>
#                 </td>
#                 <td>, syrah og cinsault .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, fruktig og korrekt rhonevin</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102848156?searchText=Enkel' target='_blank' style='text-decoration:none'>Norges beste vinkjøp 2005, Ronold, Arne, 2004</a>
#                 </td>
#                 <td>None</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>og frisk gruner med innslag</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102848156?searchText=Enkel' target='_blank' style='text-decoration:none'>Norges beste vinkjøp 2005, Ronold, Arne, 2004</a>
#                 </td>
#                 <td>kokte bær på duft .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>og svært spinkel vin med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102848156?searchText=Enkel' target='_blank' style='text-decoration:none'>Norges beste vinkjøp 2005, Ronold, Arne, 2004</a>
#                 </td>
#                 <td>og fat på duft .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>og spinkel vin med übehagelig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102848156?searchText=Enkel' target='_blank' style='text-decoration:none'>Norges beste vinkjøp 2005, Ronold, Arne, 2004</a>
#                 </td>
#                 <td>None</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>og billig spansk rødvin med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007100304037?searchText=Enkel' target='_blank' style='text-decoration:none'>Rødvin fra A til Å, Ainsworth, Jim, 1991</a>
#                 </td>
#                 <td>inspirasjon kokken eventuelt manglet .</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>vanlig mat , p ?</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007100304037?searchText=Enkel' target='_blank' style='text-decoration:none'>Rødvin fra A til Å, Ainsworth, Jim, 1991</a>
#                 </td>
#                 <td>GAMAY-SMAKEN</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>, direkte , uskyldig ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014110407702?searchText=Enkel' target='_blank' style='text-decoration:none'>komplette guiden til norsk øl, Mortensen, Hylje, 2009</a>
#                 </td>
#                 <td>Blond /</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>Bruun / Dobbel Triple /</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014062548118?searchText=Enkel' target='_blank' style='text-decoration:none'>Vinskolen, Salvesen, Geir, 2008</a>
#                 </td>
#                 <td>None</td>
#                 <td>Enkel</td>
#                 <td style='text-align:left'>/ viA ^ Zov ^</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012072638011?searchText=Enkel' target

# %%
nb.get_urnkonk('T3IH1in', {'urns':corpus_urns, 'limit':50})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072948050?searchText=T3IH1in' target='_blank' style='text-decoration:none'>På druen, Skinner, Matt, 2005</a>
#                 </td>
#                 <td>18.</td>
#                 <td>T3IH1in</td>
#                 <td style='text-align:left'>. Forskjellen mellom rødvin og</td>
#             </tr>
# </table>

# %% [markdown]
# ## Inspect collocations
#
# Let's make a huge graph. Each node is expanded. We do the exercise for both reference corpuses (corpora).

# %%
coll_corp.index[:20] # We cut off at tanninsvak (low tanin), number 11, judged from table above
# Out:
# Index(['hvitvin', 'Karbonader', 'Fordeling', 'Fettstrukturen', 'tanninholdig',
#        'rosévin', 'fiskefettet', 'tilberedningsform', 'jordbærsmakende',
#        'fordre', 'tanninsvak', 'vintype:', 'Wienersnitsel', 'T3IH1in',
#        'Suffleer', 'Kjøttfondue', 'Kjøttfondy', 'bodeaux', 'tannindominert',
#        'Hare'],
#       dtype='object')

# %%
words_to_expand = list(coll_corp.index[:11])
words_to_expand
# Out:
# ['hvitvin',
#  'Karbonader',
#  'Fordeling',
#  'Fettstrukturen',
#  'tanninholdig',
#  'rosévin',
#  'fiskefettet',
#  'tilberedningsform',
#  'jordbærsmakende',
#  'fordre',
#  'tanninsvak']

# %% [markdown]
# We want to create a collocation for each of the words, and collect all in a graph. We repeat the collocation making for each word in our list.
#
# for each word make a collocation for that word using the corpus URNs:

# %%
collocations = {word: nb.urn_coll(word, urns=corpus_urns) for word in words_to_expand}

# %% [markdown]
# We may inspect the collocations:

# %%
for w in collocations:
    print(w, list(collocations[w].index[:11]))
    print()
# Out:
# hvitvin [',', '.', 'og', 'en', 'er', 'som', 'av', 'i', 'med', 'tørr', 'til']
#
# Karbonader ['rødvin', 'Enkel', 'Kraftig', 'eller', 'rosévin', 'Kalv', 'Kjøttfondue', 'Kjøttfondy', 'Lam', 'Middels']
#
# Fordeling [')', '(', 'rødvin', '-', ':', '/', '1998', 'hvitvin', '2000', 'av', 'i']
#
# Fettstrukturen ['rødvin', 'Lam', 'en', 'i', 'lam', 'krever', '.', 'ripasso', 'pomerol', ',', '&']
#
# tanninholdig [',', 'og', 'en', 'rødvin', 'som', '.', 'er', 'av', 'mer', 'men', 'ledsages']
#
# rosévin [',', '.', 'og', 'en', 'av', 'er', 'som', 'rødvin', 'i', 'til', 'hvitvin']
#
# fiskefettet [',', 'er', 'generelt', 'ikke', 'og', 'rødvin', 'å', 'av', 'fet', 'fisk', 'grunn']
#
# tilberedningsform [',', 'en', 'men', 'og', 'også', 'rødvin', 'saus', 'tanninholdig', 'betydning', 'har', 'inn']
#
# jordbærsmakende ['og', '.', 'Beaujolais', 'bringebær-', 'frisk', 'lett', 'rødvin', 'lider', 'under', 'Frankrike', '«']
#
# fordre [',', 'animalske', 'innholdet', 'igjen', 'fettstoffer', 'en', 'om', 'av', 'tannindominert', 'rødvin', 'et']
#
# tanninsvak ['en', ',', 'med', 'rødvin', 'best', 'fungerer', 'rødvinssaus', 'eksempel', 'for', 'lett', 'f.eks.']

# %% [markdown]
# Normalize

# %%
for w in collocations:
    nb.normalize_corpus_dataframe(collocations[w])

# %% [markdown]
# These undergo same procedure as with the original

# %%
collocations_weight = {w:frame_sort(collocations[w]**1.7/corpus_tot) for w in collocations}

# %%
for w in collocations_weight:
    print(w, list(collocations_weight[w].index[:11]))
    print()
# Out:
# hvitvin ['rødvin', 'tørr', 'Fordeling', 'dl', 'skalldyrpasta', 'rød-', 'lagringssterk', 'velavkjølte', 'Ostefondy', 'Forkjærlighet', 'Tørr']
#
# Karbonader ['Kjøttfondue', 'Kjøttfondy', 'Enkel', 'Kraftig', 'rosévin', 'rødvin', 'Kalv', 'Middels', 'Lam', 'eller', " '<^Æ*"]
#
# Fordeling ['presringskjellerne', 'hvitvm', 'maktfulle', '1998', '2000', 'hvitvin', 'rødvin', 'lag-', 'fraktes', 'foto', 'druetyper']
#
# Fettstrukturen ['jfc', 'pomerol', 'ripasso', 'lam', 'Lam', 'krever', 'gruner', 'rødvin', 'østerriksk', 'veltliner', '41']
#
# tanninholdig ['tilberedningsform', 'nødvin', 'ledsages', 'syresterk', 'Grenacheoussanne,', 'Alexander-versjonen', 'alvorsfull', 'Etna-rødvin', 'bidna', 'denmed', 'Ætw']
#
# rosévin ['Chåteuneuf-du-', 'Csardas', 'overskuddsdruene', 'dangsjo', 'Grålig', 'Miinzlay.', 'Svakvinslisten', 'Karbonader', 'fremstiling', 'Rotling', 'Roseen']
#
# fiskefettet ['pga.', 'generelt', 'fet', 'fisk', 'rødvin', 'grunn', 'ikke', 'å', 'er', 'og', 'på']
#
# tilberedningsform ['tanninholdig', 'saus', 'betydning', 'rødvin', 'spiller', 'også', 'men', 'har', 'inn', 'en', 'og']
#
# jordbærsmakende ['bringebær-', 'lider', 'Beaujolais', 'frisk', 'rødvin', 'lett', 'under', 'Frankrike', 'og', '■', '«']
#
# fordre ['tannindominert', 'Maltgjøringen', 'tempereret', 'efterdi', 'fettstoffer', 'viltrettene', 'alkoholsterkere', 'animalske', 'innholdet', 'Klima', 'Gjæringen']
#
# tanninsvak ['rødvinssaus', 'fungerer', 'vindrikkende', 'Tilgjengelig', 'syrefrisk', 'Velg', 'best', 'rødvin', 'eksempel', 'f.eks.', 'lett']

# %% [markdown]
# ## Final step
#
# Turn it all into a graph. Create a graph and populate it with edges.

# %%
# start with an empty list of edges

edges = []

# %%
# add elements from words_to_expand

for x in words_to_expand:
    edges.append((collword, x, float(coll_corp.loc[x])))

# %% [markdown]
# After the first edges are added, we can have a look at them

# %%
edges
# Out:
# [('rødvin', 'hvitvin', 1.2410430806682913),
#  ('rødvin', 'Karbonader', 1.1112348431624819),
#  ('rødvin', 'Fordeling', 0.719081595704026),
#  ('rødvin', 'Fettstrukturen', 0.4813867563749885),
#  ('rødvin', 'tanninholdig', 0.4696366627846646),
#  ('rødvin', 'rosévin', 0.466142683123054),
#  ('rødvin', 'fiskefettet', 0.4444939372649928),
#  ('rødvin', 'tilberedningsform', 0.40753764964363914),
#  ('rødvin', 'jordbærsmakende', 0.37041161438749404),
#  ('rødvin', 'fordre', 0.3610400672812414),
#  ('rødvin', 'tanninsvak', 0.3610400672812414)]

# %% [markdown]
# Create a graph over the edges

# %%
G = nx.Graph()

# %% [markdown]
# Add the edges

# %%
G.add_weighted_edges_from(edges)

# %% [markdown]
# Draw the graph using module gnl

# %%
gnl.show_graph(G)

# %% [markdown]
# Next add all the edges from `collocations_weight`. We just select the 11 first, just like the first. This could be made sensitive to the actual structure of the collocation.

# %%
rest_edges = []

# %%
for w in collocations_weight:
    for word in collocations_weight[w].index[:11]:
        rest_edges.append((w, word, float(collocations_weight[w].loc[word])))

# %% [markdown]
# Add the latest edges to G

# %%
G.add_weighted_edges_from(rest_edges)

# %%
gnl.show_graph(G, spread = 0.3)
