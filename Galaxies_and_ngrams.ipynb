# %% [markdown]
# ### Preamble
#
# Contains imports and some utility code.

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
update('nbtext', overwrite=True)  # may remove overwrite=True
update('graph_networkx_louvain', overwrite=True)
import graph_networkx_louvain as gnl
import nbtext as nb
import networkx as nx
# %matplotlib inline
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Tutorial-DHN2019\nbtext.py`
# Updated file `C:\Users\larsj\Documents\GitHub\Tutorial-DHN2019\graph_networkx_louvain.py`

# %%
def frame_sort(frame, by=0):
    return frame.sort_values(by=by, ascending=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # N-grams
#
# Only Norwegian

# %%
nb.nb_ngram('han, hun', smooth=1, years=(1950, 1990)).plot(figsize=(10,5), lw=3)

# %% [markdown]
# # Galaxies
#
# Norwegian from National Library, English and German from Google N-grams.
#
# Use it to analyse places, names, word hierarchies. Galaxies are a kind of word vectors constructed from trigrams on the form "X and Y" for English, "X og Y" for Norwegian, and "X und Y" for German. Recursively two depths.

# %%
ice = nb.make_graph('ice', lang='eng')

# %%
gnl.show_graph(ice, spread=0.5)

# %%
Eis = nb.make_graph('Eis', lang='ger')

# %%
gnl.show_graph(Eis, spread=0.5)

# %% [markdown]
# # German has the drug reading!
#
# For any graph, use command `show_communities` from `gnl` to have a look at the clusters, or use `community_dict` for analytical purposes.

# %%
gnl.show_communities(Eis)
# Out:
# Schnee-Reif :  Schnee, Reif, Firn, Hagel, Glatteis, Nebel, Gletschereis, Graupeln, Tau
#
# Frost-Kälte :  Frost, Kälte, Glut, Nässe, Hitze, Eisgang, Asche, Schneefall, Tauwetter, Gefühllosigkeit, Innigkeit, Schneegestöber, Zugluft
#
# Eis-Hochwasser :  Eis, Hochwasser, Regen, Niedrigwasser, Schmelzwasser
#
# Gletscher-Gletschern :  Gletscher, Gletschern, Lawinen, Firnen, Firnfeldern, Eisberge, Inlandeis, Firne, Schneefelder, Firnfelder, Schneefeldern
#
# Kuchen-Limonade :  Kuchen, Limonade, Bier, Kaffee, Torten, Kekse, Gebäck
#
# Opium-Belladonna :  Opium, Belladonna, Morphin, Campher, Morphium, Kampher, Haschisch
#
# Kochsalz-Salmiak :  Kochsalz, Salmiak, Harnstoff, Alaun, Glaubersalz, Salpeter
#
# Fels-Schutt :  Fels, Schutt, Geröll, Hort

# %%
gnl.community_dict(Eis)
# Out:
# {'Schnee-Reif': ['Schnee',
#   'Reif',
#   'Firn',
#   'Hagel',
#   'Glatteis',
#   'Nebel',
#   'Gletschereis',
#   'Graupeln',
#   'Tau'],
#  'Frost-Kälte': ['Frost',
#   'Kälte',
#   'Glut',
#   'Nässe',
#   'Hitze',
#   'Eisgang',
#   'Asche',
#   'Schneefall',
#   'Tauwetter',
#   'Gefühllosigkeit',
#   'Innigkeit',
#   'Schneegestöber',
#   'Zugluft'],
#  'Eis-Hochwasser': ['Eis',
#   'Hochwasser',
#   'Regen',
#   'Niedrigwasser',
#   'Schmelzwasser'],
#  'Gletscher-Gletschern': ['Gletscher',
#   'Gletschern',
#   'Lawinen',
#   'Firnen',
#   'Firnfeldern',
#   'Eisberge',
#   'Inlandeis',
#   'Firne',
#   'Schneefelder',
#   'Firnfelder',
#   'Schneefeldern'],
#  'Kuchen-Limonade': ['Kuchen',
#   'Limonade',
#   'Bier',
#   'Kaffee',
#   'Torten',
#   'Kekse',
#   'Gebäck'],
#  'Opium-Belladonna': ['Opium',
#   'Belladonna',
#   'Morphin',
#   'Campher',
#   'Morphium',
#   'Kampher',
#   'Haschisch'],
#  'Kochsalz-Salmiak': ['Kochsalz',
#   'Salmiak',
#   'Harnstoff',
#   'Alaun',
#   'Glaubersalz',
#   'Salpeter'],
#  'Fels-Schutt': ['Fels', 'Schutt', 'Geröll', 'Hort']}

# %% [markdown]
# More than one word can be added

# %%
positive = nb.make_graph('good, nice, wedding, party', lang='eng')

# %%
gnl.show_graph(positive, spread=0.5)

# %%
gnl.show_communities(positive)
# Out:
# chearfulness-hellos :  chearfulness, hellos, good, smiles, joy, serenity, gaiety, hugs, goodbyes, handshakes, alacrity, husbandlike, spials, tenantable
#
# contrivances-subtile :  contrivances, subtile, wranglings, subtilties, disputes, refinements, stratagems, abstruse, knotty, makeshifts, craftie, inventions, artifices, quarrels, bickerings, expedients
#
# bridesmaids-trousseau :  bridesmaids, trousseau, dowries, gowns, bridesmen, gown, ushers, gifts, groomsmen, furniture, bride, inheritances, presents, wills
#
# cosy-nice :  cosy, nice, cozy, neat, tidy, comfy, cosey, warm, snug, comfortable, homelike, toasty, inviting, homey, clean, cleanly, shipshape, dry, prim, Warm, homely, quaint, workmanlike, welcoming, trim, waterish
#
# christening-baptismal :  christening, baptismal, weddings, burial, funeral, baptism, launching, naming, Birth, matrimonial, birth, eucharistic, communion, marrying, confirmation
#
# birthdays-anniversaries :  birthdays, anniversaries, namedays, Christmas, holidays, Christmases, christenings, graduations
#
# party-officeholders :  party, officeholders, Komsomol, soviet, nonparty, Party, beguiles, Partisanship, Communist, legislators, union, heelers, bosses, Pioneer, Pioneers, Ideology, candidates, noisemakers, activists, communists, politicians, deceives, bureaucrats, komsomol, voters, Communists, collective, Gibault, Whips, hustlin, fraternally, relator
#
# wedding-engagement :  wedding, engagement, honeymoon, wooing, betrothal, reception, courtship, marriage, Betrothal, Marriage, Wedding, courting, dowry, musicale, Courtship, ceremony, interactivity, winning, attentiveness, impartation, spectatorship, disengagement, cooing, trousseaux, soft, vacation, matrimony, sorrowe
#
# perfidy-dissimulation :  perfidy, dissimulation, ingratitude, baseness, cruelty, faithlessness, duplicity, treachery
#
# plunders-robs :  plunders, robs, ravages, robberies, oppresses
#
# pemmican-biscuits :  pemmican, biscuits, jerky, furs, biscuit, cocoa
#
# coronation-nuptials :  coronation, nuptials, anointment, enthronement, anointing, unction, consecration, investiture
#
# catchwords-slogans :  catchwords, slogans, cliches, shibboleths, phrases, signatures
#
# naughty-disobedient :  naughty, disobedient, mischievous
#
# finical-squeamish :  finical, squeamish, fastidious, delicate, affected
#
# pigtails-tuxedos :  pigtails, tuxedos, hats, pinafores, bangs, braces, freckles, dresses

# %%
Churchill_eng = nb.make_graph("Churchill", lang='eng')
Churchill_nob = nb.make_graph("Churchill", lang='nob')
Churchill_ger = nb.make_graph("Churchill", lang='ger')

# %%
gnl.show_graph(Churchill_eng)

# %%
gnl.show_graph(Churchill_ger, spread=0.7)

# %%
gnl.show_graph(Churchill_nob, spread=0.8)

# %% [markdown]
# # Exercise
#
# What about cities?
