# %% [markdown]
# ### Preamble

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ## Growth diagrams

# %%
import nbtext as nb
from nbtext import vekstdiagram, make_graph, get_urn, relaterte_ord

# %matplotlib inline

# %% [markdown]
# ## Finn bøker
#
# Benytt kommandoen _get_urn()_ for å hente urner basert på kategorier av bøker

# %%
# Hent URN-er, lag korpus med get_urn()

urner = get_urn({
    'author':'masterson%lou%', 
    'year':1900, 
    'neste':160,
    'limit':100,
    'title':'%kane%'
    
})

urner
# Out:
# [[2014060408186, 'Masterson, Louis', 'Cuba libre! ; Satans Kane!', 2008],
#  [2014030606053,
#   'Masterson, Louis',
#   'Satans horn ; Morgan Kane og "The Wild Bunch"',
#   2007],
#  [2013070108113, 'Masterson, Louis', "Kane's kvinner", 1974],
#  [2014100338013, 'Masterson, Louis', "Menneskejeger ; Kane's kvinner", 2007],
#  [2015102208249, 'Masterson, Louis', "Kane's colt", 1975],
#  [2013041908141, 'Masterson, Louis', "Kane's våpen", 1971],
#  [2014060408222,
#   'Masterson, Louis',
#   'Kanes stjerne ; Heltene er trette',
#   2008],
#  [2016060108119, 'Masterson, Louis', "Kane's likemann", 1970],
#  [2010092808038, 'Masterson, Louis', "Kane's våpen", 1974],
#  [2013042338041, 'Masterson, Louis', '"Killer" Kane', 1970],
#  [2011100608069,
#   'Masterson, Louis',
#   'Duell i Tombstone ; Dette er døden, señor Kane',
#   2005],
#  [2013070108111, 'Masterson, Louis', 'Morgan Kane og "The wild bunch"', 1980],
#  [2012062205112, 'Masterson, Louis', 'Morgan Kane og smuglerne', 2010],
#  [2007081700037, 'Masterson, Louis', 'Ingen tårer for Morgan Kane', 1989],
#  [2014062405095, 'Masterson, Louis', 'Dette er døden, señor Kane', 2011],
#  [2013042508132, 'Masterson, Louis', "I Morgan Kane's fotspor", 1975],
#  [2014100338012, 'Masterson, Louis', "Oklahoma terror ; Kane's colt", 2006],
#  [2013042308035, 'Masterson, Louis', "Kane's stjerne", 1985],
#  [2015111008044, 'Masterson, Louis', 'Morgan Kane og "The Wild Bunch"', 1976],
#  [2007071601101, 'Masterson, Louis', 'Legenden om Morgan Kane', 1973],
#  [2013052908062, 'Masterson, Louis', 'Morgan Kane - menneskejeger', 1975],
#  [2013070108115, 'Masterson, Louis', "Kane's likemann", 1970],
#  [2013042508134, 'Masterson, Louis', "Kane's colt", 1971],
#  [2009012204004,
#   'Masterson, Louis',
#   'I Morgan Kanes fotspor ; Blodsporet til Santa Fe',
#   2002],
#  [2007070300049, 'Masterson, Louis', '"Killer" Kane', 1981],
#  [2013060708079, 'Masterson, Louis', 'Satans Kane!', 1976],
#  [2013041608022, 'Masterson, Louis', 'Ingen tårer for Morgan Kane', 1967],
#  [2013070108066, 'Masterson, Louis', "Morgan Kane's lov", 1974],
#  [2013080808047, 'Masterson, Louis', "I Morgan Kane's fotspor", 1980],
#  [2015111008045, 'Masterson, Louis', 'Dette er døden, sẽnor Kane', 1980],
#  [2013070108110, 'Masterson, Louis', 'Morgan Kane - menneskejeger', 1971]]

# %% [markdown]
# Indeksen kan brukes sammen **urner[]** for å referere til en bok. Referansen og **urner[]** kan brukes om hverandre.

# %% [markdown]
# ### Sett av ord for å sjekke mot.
#
# For å lage et sett ord, er det ikke verre enn å bare liste opp ord som kan passe. For hjelp til å konstruere et passende sett av ord er kommandoen `relaterte_ord(startord)` grei å bruke; den samler sammen en del ord semantisk knyttet til `startord`. Samme operasjon som vises under galakser i NB N-gram.

# %%
kampord = """kuler kulen kulene revolver revolveren
gevær geværet krutt kruttet hylse hylsen
skuddet sår skudd såret blod blodet skadet
skadene slag slagene slaget spark sparket""".split()

# %%
glad = relaterte_ord('munter, avslappet, plystret, lettet', 140)
glad
# Out:
# ['glad',
#  'fornøyd',
#  'lykkelig',
#  'tilfreds',
#  'avslappet',
#  'vennlig',
#  'smilende',
#  'rolig',
#  'lettet',
#  'hyggelig',
#  'takknemlig',
#  'stolt',
#  'elskverdig',
#  'blid',
#  'rørt',
#  'munter',
#  'selvsikker',
#  'morsom',
#  'harmonisk',
#  'hjelpsom',
#  'imøtekommende',
#  'opplagt',
#  'uhøytidelig',
#  'underholdende',
#  'trygg',
#  'livlig',
#  'optimistisk',
#  'glade',
#  'omgjengelig',
#  'behagelig',
#  'høflig',
#  'uformell',
#  'übekymret',
#  'spøkefull',
#  'overrasket',
#  'tilbakelent',
#  'avspent',
#  'forståelsesfull',
#  'sjarmerende',
#  'sorgløs',
#  'lærerik',
#  'solrikt',
#  'oppmuntrende',
#  'opprømt',
#  'fornøyde',
#  'uanstrengt',
#  'pratsom',
#  'grei',
#  'forekommende',
#  'kjærlig',
#  'naturlig',
#  'lykkelige',
#  'våkner',
#  'ettertenksom',
#  'fredelig',
#  'likevektig',
#  'interessant',
#  'velspilt',
#  'skuffet',
#  'provoserende',
#  'ydmyk',
#  'takksam',
#  'trivelig',
#  'morsomt',
#  'vennlige',
#  'intelligent',
#  'nikket',
#  'rasende',
#  'vittig',
#  'direkte',
#  'omtenksom',
#  'upretensiøst',
#  'blide',
#  'aktiv',
#  'utadvendt',
#  'übesværet',
#  'beroligende',
#  'fløy',
#  'forsvant',
#  'tankevekkende',
#  'spennende',
#  'kvikk',
#  'omsorgsfull',
#  'vinkende',
#  'serviceinnstilt',
#  'intimt',
#  'attraktivt',
#  'barnev',
#  'veletablert',
#  'barnevennlig',
#  'dypt',
#  'etablert',
#  'usjenert',
#  'sindig',
#  'avbalansert',
#  'kjempeglad',
#  'stolte',
#  'beroliget',
#  'imponert',
#  'travelt',
#  'hektisk',
#  'uformelt',
#  'aktivt',
#  'hjemlig',
#  'avslappende',
#  'humoristisk',
#  'kry',
#  'flink',
#  'kjempeflink',
#  'beæret',
#  'arrogant',
#  'takknemlige',
#  'elegant',
#  'utfordrende',
#  'medgjørlig',
#  'snill',
#  'positiv',
#  'livsglad',
#  'våken',
#  'forvirret',
#  'beveget',
#  'begeistret',
#  'overveldet',
#  'vakker',
#  'komfortabel',
#  'fin',
#  'fargerik',
#  'original',
#  'rytmisk',
#  'godt',
#  'vakkert',
#  'tilfredse',
#  'oppvakt',
#  'oversiktlig',
#  'folkelig',
#  'forutsigbar',
#  'tillitsfull',
#  'muntert',
#  'livlige',
#  'muntre']

# %%
tilfeldige_ord =  "revolver hjalp snerret freste tennene pannen nevene neven hansken Smith beltet kinnet slaget kulen kulene skuddet traff sneiet ørken hesten".split()

# %% [markdown]
# ## Lag et vekstdiagram for bøker i korpuset
#
# Bruk et av elementene i trefflisten

# %%
vekstdiagram( [2015111008045, 'Masterson, Louis', 'Dette er døden, sẽnor Kane', 1980], {'words': glad, 'window':5000, 'pr':100}).plot()

# %%
vekstdiagram(2015111008045,{'words': kampord, 'window':5000, 'pr':100}).plot()

# %% [markdown]
# ## Co-plot

# %%
nb.plot_sammen_vekst(2015111008045, [glad, kampord], window =5000,pr=50 ).plot(figsize=(15,8));
# Out:
# C:\Users\larsj\Documents\GitHub\Bazaar\nbtext.py:931: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat(rammer)

# %%
nb.plot_sammen_vekst(2013041908141, [glad, kampord], window =5000,pr=50 ).plot(figsize=(15,8));
# Out:
# C:\Users\larsj\Documents\GitHub\Bazaar\nbtext.py:931: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat(rammer)

# %%
nb.plot_sammen_vekst(2011052313001, [glad, kampord], window =5000,pr=50 ).plot(figsize=(15,8));
# Out:
# C:\Users\larsj\Documents\GitHub\Bazaar\nbtext.py:931: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat(rammer)

# %%
max_ = get_urn({'author':"solstad%dag%",'title':"%prof%", 'year':1990, 'next':30, 'limit':100})

# %%
np = nb.get_papers(navn="aftenposten", yearfrom=1990, yearto=1991, samplesize=20)

# %%
np = _23

# %%
npf = nb.frame(np).transpose()

# %%
nb.heatmap(npf.sort_values(by=0, ascending=False)[:20])
# Out:
# <style  type="text/css" >
#     #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col0 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col1 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col2 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col3 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col4 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col5 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col6 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col7 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col8 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col9 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col10 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col11 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col12 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col13 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col14 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col15 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col16 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col17 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col18 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow0_col19 {
#             background-color:  #008000;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col0 {
#             background-color:  #45a645;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col1 {
#             background-color:  #46a746;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col2 {
#             background-color:  #4dab4d;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col3 {
#             background-color:  #44a544;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col4 {
#             background-color:  #47a747;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col5 {
#             background-color:  #3ba13b;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col6 {
#             background-color:  #3ea23e;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col7 {
#             background-color:  #3da23d;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col8 {
#             background-color:  #4caa4c;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col9 {
#             background-color:  #5eb45e;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col10 {
#             background-color:  #54ae54;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col11 {
#             background-color:  #45a645;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col12 {
#             background-color:  #359d35;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col13 {
#             background-color:  #309a30;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col14 {
#             background-color:  #57b057;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col15 {
#             background-color:  #57b057;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col16 {
#             background-color:  #48a848;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col17 {
#             background-color:  #45a645;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col18 {
#             background-color:  #56af56;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow1_col19 {
#             background-color:  #309a30;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col0 {
#             background-color:  #c1ebc1;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col1 {
#             background-color:  #bbe8bb;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col2 {
#             background-color:  #c8efc8;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col3 {
#             background-color:  #bee9be;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col4 {
#             background-color:  #a4dba4;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col5 {
#             background-color:  #84c984;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col6 {
#             background-color:  #b0e1b0;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col7 {
#             background-color:  #74c074;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col8 {
#             background-color:  #9dd79d;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col9 {
#             background-color:  #9fd89f;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col10 {
#             background-color:  #bbe8bb;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col11 {
#             background-color:  #bee9be;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col12 {
#             background-color:  #5db35d;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col13 {
#             background-color:  #72bf72;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col14 {
#             background-color:  #87cb87;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col15 {
#             background-color:  #acdfac;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col16 {
#             background-color:  #c2ebc2;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col17 {
#             background-color:  #5db35d;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col18 {
#             background-color:  #bde9bd;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow2_col19 {
#             background-color:  #a7dda7;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col0 {
#             background-color:  #c6eec6;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col1 {
#             background-color:  #b0e2b0;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col2 {
#             background-color:  #c8efc8;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col3 {
#             background-color:  #cff3cf;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col4 {
#             background-color:  #cdf2cd;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col5 {
#             background-color:  #d3f5d3;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col6 {
#             background-color:  #cdf2cd;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col7 {
#             background-color:  #cef2ce;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col8 {
#             background-color:  #cdf2cd;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col9 {
#             background-color:  #c5edc5;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col10 {
#             background-color:  #c6eec6;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col11 {
#             background-color:  #ccf1cc;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col12 {
#             background-color:  #cff3cf;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col13 {
#             background-color:  #d0f3d0;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col14 {
#             background-color:  #c8efc8;
#         }    #T_89c2d298_14d5_11e9_baee_d46d6d080fecrow3_col15 {
#             background-color:  #cdf2cd;
#         }    #T_89c2d298_14d5_11e9_baee_d46

# %%
nb.plot_sammen_vekst(2013041908141, [glad, kampord], window =5000,pr=50 ).plot(figsize=(15,8));
# Out:
# C:\Users\larsj\Documents\GitHub\Bazaar\nbtext.py:931: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat(rammer)

# %%
nb.get_freq(2013041908141)
# Out:
# Counter({'.': 3079,
#          ',': 1980,
#          'og': 1074,
#          'i': 790,
#          'Kane': 661,
#          'på': 631,
#          'en': 551,
#          'han': 530,
#          'det': 496,
#          'var': 487,
#          'av': 477,
#          '?': 394,
#          'Han': 361,
#          'som': 356,
#          '!': 334,
#          'sa': 312,
#          'å': 311,
#          'den': 307,
#          'med': 303,
#          'seg': 302,
#          'ikke': 287,
#          'til': 282,
#          'hadde': 282,
#          "'": 262,
#          'er': 255,
#          'så': 247,
#          'for': 239,
#          'de': 225,
#          'Det': 225,
#          'et': 224,
#          'at': 221,
#          's': 203,
#          'De': 170,
#          'ham': 167,
#          'Jeg': 156,
#          'jeg': 147,
#          'ut': 140,
#          ':': 126,
#          'Kr': 118,
#          'våpen': 115,
#          'du': 113,
#          'opp': 109,
#          'om': 108,
#          'har': 108,
#          'fra': 107,
#          'hans': 103,
#          'over': 99,
#          'ble': 94,
#          'mot': 93,
#          'Swede': 85})

# %%
nb.get_urnkonk('såret',{'urns':[2013041908141]})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908141?searchText=såret' target='_blank' style='text-decoration:none'>Kane's våpen, Masterson, Louis, 1971</a>
#                 </td>
#                 <td>så sukket han dypt og</td>
#                 <td>såret</td>
#                 <td style='text-align:left'>og falt overende og kreket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908141?searchText=såret' target='_blank' style='text-decoration:none'>Kane's våpen, Masterson, Louis, 1971</a>
#                 </td>
#                 <td>William De Fabre ble stygt</td>
#                 <td>såret</td>
#                 <td style='text-align:left'>da han kastet seg frem</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908141?searchText=såret' target='_blank' style='text-decoration:none'>Kane's våpen, Masterson, Louis, 1971</a>
#                 </td>
#                 <td>Fabre . Han ble dessverre</td>
#                 <td>såret</td>
#                 <td style='text-align:left'>under . . . hm</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908141?searchText=såret' target='_blank' style='text-decoration:none'>Kane's våpen, Masterson, Louis, 1971</a>
#                 </td>
#                 <td>sa Frazer lavt , nesten</td>
#                 <td>såret</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# </table>
